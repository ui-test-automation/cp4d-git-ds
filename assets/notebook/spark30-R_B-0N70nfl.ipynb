# %%
library("SparkR")
data_df_0 <- read.df('/project_data/data_asset/dataSetDemo_csv_d1zbslxjolnzn5x1lbo8b4wf2.csv', source = 'csv')
showDF(data_df_0, numRows = 5, truncate = TRUE)
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20210114013748-0000
# KERNEL_ID = 7d4e93f8-7852-4eeb-9ca6-383cc78c8006
# +----+-----------------+-----------------+----------------+---------+--------+
# | _c0|              _c1|              _c2|             _c3|      _c4|     _c5|
# +----+-----------------+-----------------+----------------+---------+--------+
# |Year|     Product line|Order method type|Retailer country|  Revenue|Quantity|
# |2004|Camping Equipment|        Telephone|   United States|315044.33|   66385|
# |2004|Camping Equipment|        Telephone|          Canada| 13444.68|    2172|
# |2004|Camping Equipment|        Telephone|          Mexico|     null|    null|
# |2004|Camping Equipment|        Telephone|          Brazil|     null|    null|
# +----+-----------------+-----------------+----------------+---------+--------+
# only showing top 5 rows

# %%
df_data_1 <- read.csv(file = '/project_data/data_asset/Female_human_trafficking_csv_ey90lp7ru1pyyuw7157433ahg.csv', header = TRUE, sep = ",")
head(df_data_1)
# Out:
#   X VETTING_LEVEL DESCRIPTION VETTING_LEVEL_PREDICTION ALGORITHM_NAME
# 1 1 100           NA          30                       DECISION_TREE
# 2 2  30           NA          30                       DECISION_TREE
# 3 3 100           NA          30                       DECISION_TREE
# 4 4 100           NA          30                       DECISION_TREE
# 5 5  30           NA          30                       DECISION_TREE
# 6 6 100           NA          30                       DECISION_TREE
#   ALT_NAME                 GENDER BIRTH_DATE BIRTH_COUNTRY BIRTH_COUNTRY_CODE
# 1 Kathleen Bailey          FALSE  1985-11-27 Ghana         GH
# 2 Kelly Robbins            FALSE  1971-01-17 Pakistan      PK
# 3 Linda Stewart            FALSE  1997-04-15 Ghana         GH
# 4 Stacey Courtney Gonzalez FALSE  1984-03-27 Ghana         GH
# 5 Erika Patie Fowler       FALSE  1998-06-18 Ghana         GH
# 6 Ashlee Fisher            FALSE  1981-01-05 Ghana         GH
# ...

# %%
# Out:
# Error in eval(expr, envir, enclos): object 'sc.version' not found
# Traceback:
