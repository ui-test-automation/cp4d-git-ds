# %%
df_data_1 <- read.csv(file = '/project_data/data_asset/datalake_names.csv', header = TRUE, sep = ",")
head(df_data_1)
# Out:
#   Number Gender NameSet  Title GivenName MiddleInitial Surname
# 1 1      female American Mrs.  Susan     G             Buck
# 2 2      male   American Mr.   Charles   M             Black
# 3 3      female American Ms.   Norine    R             Breese
# 4 4      female American Ms.   Leila     A             Woodall
# 5 5      male   American Mr.   James     D             Banh
# 6 6      male   American Mr.   Forrest   G             Taormina
#   StreetAddress           City        State ... Vehicle
# 1 3107 Fittro Street      Little Rock AR    ... 2015 Lexus IS 350
# 2 496 Neuport Lane        Smyrna      GA    ... 1999 Honda City
# 3 3888 Buffalo Creek Road Nashville   TN    ... 2010 Alfa Romeo Brera
# 4 4174 Smith Street       Walpole     MA    ... 1999 Ferrari 360
# 5 2474 Ventura Drive      Salinas     CA    ... 2005 TVR Tamora
# 6 292 Kelly Street        Charlotte   NC    ... 2003 Kia Retona
#   Domain              BloodType Pounds Kilograms FeetInches Centimeters
# ...

# %%
library(projectLib)
project <- projectLib::Project$new()
storage_credentials <- project$get_storage_metadata()
