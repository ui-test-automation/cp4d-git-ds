# %%
import pandas as pd

df_data_1 = pd.read_csv('/project_data/data_asset/CensusIncome_csv_drh6oxmia19lykiw9gy93gfzr.csv')
df_data_1.head()
# Out:
#    age          workclass  Financial-Weight   education  education-num  \
# 0   39          State-gov             77516   Bachelors             13
# 1   50   Self-emp-not-inc             83311   Bachelors             13
# 2   38            Private            215646     HS-grad              9
# 3   53            Private            234721        11th              7
# 4   28            Private            338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country SalaryOver50k
# ...

# %%
df_data_2 = pd.read_csv('/project_data/data_asset/Customer_analysis_csv_1rzg3ulwe1gzzpucmwuczdecj.csv')
df_data_2.head()
# Out:
#   Customer ID       State  Customer Lifetime Value  Coverage Education  \
# 0     BU79786  Washington                     2764     Basic  Bachelor
# 1     QZ44356     Arizona                     6980  Extended  Bachelor
# 2     AI49188      Nevada                    12887   Premium  Bachelor
# 3     WW63253  California                     7646     Basic  Bachelor
# 4     HB64268  Washington                     2814     Basic  Bachelor
#
#   Expiry Date Employment Status Gender  Income Location Type  ...  \
# 0   5/28/2018          Employed      F   56274      Suburban  ...
# 1  10/31/2018        Unemployed      F       0      Suburban  ...
# 2   9/14/2018          Employed      F   48767      Suburban  ...
# 3    1/4/2018        Unemployed      M       0      Suburban  ...
# 4   7/26/2018          Employed      M   43836         Rural  ...
#
#   Months Since Policy Inception  Number of Open Complaints  \
# 0                             5                          0
# ...
